# %%
from bing_image_downloader.downloader import download

query_string = 'tulip'

download(query_string, limit=100000,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to E:\patent\dataset\tulip
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://1.bp.blogspot.com/--G23TLx4tjw/UwuAVxsor-I/AAAAAAAAASo/sfoXRleCFw0/s1600/Tulip+spp+from+Floriade_Canberra+by+John+O'Neill.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.pixelstalk.net/wp-content/uploads/2014/12/Red-Tulip-Flowers-Hd-Wallpapers-Backgrounds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://thedailygardener.org/wp-content/uploads/2019/08/Tulips.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.gardeningknowhow.com/wp-content/uploads/2008/07/tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.pixelstalk.net/wp-content/uploads/2014/12/Pink-Tulip-flowers-images-and-wallpapers.jpg
# [%] File Downloaded !
#
# ...

# %%
# !pip install bing-image-downloader
